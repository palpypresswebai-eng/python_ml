# %%
# !pip install matplotlib
# Out:
# ...
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ----- ---------------------------------- 1.0/8.1 MB 7.1 MB/s eta 0:00:01
#    --------------------------- ------------ 5.5/8.1 MB 16.0 MB/s eta 0:00:01
#    ---------------------------------------- 8.1/8.1 MB 15.7 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    ---------------------------------------- 2.3/2.3 MB 25.5 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/7.0 MB ? eta -:--:--
#    --------------------- ------------------ 3.7/7.0 MB 19.8 MB/s eta 0:00:01
#    ---------------------------------------  6.8/7.0 MB 19.1 MB/s eta 0:00:01
#    ---------------------------------------- 7.0/7.0 MB 16.6 MB/s eta 0:00:00
# ...
#
#    ---------------------------------------- 0/7 [pyparsing]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
# ...

# %%
import matplotlib.pyplot as plt

x = [5,6,8,9]
y = [5,6,28,48]

pt = plt.plot(x,y)

# %%
pt = plt.plot(x,y , color="red",linestyle="--",marker="o")

# %%
x = [1,2,3,4,5]
y = [1,4,9,16,25]
y1 = [1,2,3,4,5]


plt.Figure(figsize=(9,5))
plt.subplot(2, 2, 1)
plt.plot(x,y,color="green")
plt.title("plot 1")


plt.subplot(2, 2, 2)
plt.plot(x,y,color="red")
plt.title("plot 1")

plt.subplot(2, 2, 3)
plt.plot(x,y,color="blue")
plt.title("plot 1")

plt.subplot(2, 2, 4)
plt.plot(x,y,color="black")
plt.title("plot 1")
# Out:
# Text(0.5, 1.0, 'plot 1')

# %%
import pandas as pd

sale_data=pd.read_csv('sales_data.csv')
sale_data.head(5)
# Out:
#    Transaction ID        Date Product Category             Product Name  \
# 0           10001  2024-01-01      Electronics            iPhone 14 Pro
# 1           10002  2024-01-02  Home Appliances         Dyson V11 Vacuum
# 2           10003  2024-01-03         Clothing         Levi's 501 Jeans
# 3           10004  2024-01-04            Books        The Da Vinci Code
# 4           10005  2024-01-05  Beauty Products  Neutrogena Skincare Set
#
#    Units Sold  Unit Price  Total Revenue         Region Payment Method
# 0           2      999.99        1999.98  North America    Credit Card
# 1           1      499.99         499.99         Europe         PayPal
# 2           3       69.99         209.97           Asia     Debit Card
# 3           4       15.99          63.96  North America    Credit Card
# 4           1       89.99          89.99         Europe         PayPal

# %%
product_total = sale_data.groupby('Product Category')['Total Revenue'].sum()
product_total
# Out:
# Product Category
# Beauty Products     2621.90
# Books               1861.93
# Clothing            8128.93
# Electronics        34982.41
# Home Appliances    18646.16
# Sports             14326.52
# Name: Total Revenue, dtype: float64

# %%
product_total.plot(kind="bar",color="teal")
product_total
# Out:
# Product Category
# Beauty Products     2621.90
# Books               1861.93
# Clothing            8128.93
# Electronics        34982.41
# Home Appliances    18646.16
# Sports             14326.52
# Name: Total Revenue, dtype: float64

# %%
sale_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 240 entries, 0 to 239
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Transaction ID    240 non-null    int64
#  1   Date              240 non-null    object
#  2   Product Category  240 non-null    object
#  3   Product Name      240 non-null    object
#  4   Units Sold        240 non-null    int64
#  5   Unit Price        240 non-null    float64
#  6   Total Revenue     240 non-null    float64
#  7   Region            240 non-null    object
#  8   Payment Method    240 non-null    object
# dtypes: float64(2), int64(2), object(5)
# memory usage: 17.0+ KB

# %%
sale_data.groupby('Date')[['Total Revenue', 'Region']].sum().reset_index()
plt.plot(sale_data['Date'],sale_data['Total Revenue'],sale_data['Region'])
